# %%
import pandas as pd

# %%
mr = pd.read_html('https://en.wikipedia.org/wiki/List_of_cities_by_homicide_rate')

# %%
mr[0][0:5]
# Out:
#    Rank      City Country  Homicides (2019)  Population (2019)  \
# 0     1   Tijuana  Mexico              2367            1763197
# 1     2    Juárez  Mexico              1522            1455923
# 2     3   Uruapan  Mexico               301             351823
# 3     4  Irapuato  Mexico               723             895515
# 4     5   Obregón  Mexico               281             348154
#
#    Homicides per 100,000 per year
# 0                          134.24
# 1                          104.54
# 2                           85.54
# 3                           80.74
# 4                           80.72

# %%
top_homicide_cities = mr[0][['Country','City','Homicides (2019)']]
top_homicide_cities[:10]
# Out:
#          Country                  City  Homicides (2019)
# 0         Mexico               Tijuana              2367
# 1         Mexico                Juárez              1522
# 2         Mexico               Uruapan               301
# 3         Mexico              Irapuato               723
# 4         Mexico               Obregón               281
# 5      Venezuela               Caracas              2134
# 6         Mexico              Acapulco               600
# 7   South Africa             Cape Town              3065
# 8  United States             St. Louis               194
# 9         Brazil  Vitória da Conquista               205

# %% [markdown]
# # LOC
# Search for labels

# %%
top_homicide_cities.loc[:]
# Out:
#           Country                                 City  Homicides (2019)
# 0          Mexico                              Tijuana              2367
# 1          Mexico                               Juárez              1522
# 2          Mexico                              Uruapan               301
# 3          Mexico                             Irapuato               723
# 4          Mexico                              Obregón               281
# 5       Venezuela                              Caracas              2134
# 6          Mexico                             Acapulco               600
# 7    South Africa                            Cape Town              3065
# 8   United States                            St. Louis               194
# 9          Brazil                 Vitória da Conquista               205
# 10  United States                            Baltimore               348
# 11      Venezuela                       Ciudad Guayana               462
# ...

# %%
top_homicide_cities.loc[:10, ['Country', 'City']]
# Out:
#           Country                  City
# 0          Mexico               Tijuana
# 1          Mexico                Juárez
# 2          Mexico               Uruapan
# 3          Mexico              Irapuato
# 4          Mexico               Obregón
# 5       Venezuela               Caracas
# 6          Mexico              Acapulco
# 7    South Africa             Cape Town
# 8   United States             St. Louis
# 9          Brazil  Vitória da Conquista
# 10  United States             Baltimore

# %%
top_homicide_cities.columns
# Out:
# Index(['Country', 'City', 'Homicides (2019)'], dtype='object')

# %%
top_homicide_cities.loc[:10, ['Homicides (2019)']] * -1
# Out:
#     Homicides (2019)
# 0              -2367
# 1              -1522
# 2               -301
# 3               -723
# 4               -281
# 5              -2134
# 6               -600
# 7              -3065
# 8               -194
# 9               -205
# 10              -348

# %%
top_homicide_cities.loc[:10, ['Country']] == 'Mexico'
# Out:
#     Country
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False

# %% [markdown]
# # ILOC
# Search for index

# %%
top_homicide_cities.iloc[:10]
# Out:
#          Country                  City  Homicides (2019)
# 0         Mexico               Tijuana              2367
# 1         Mexico                Juárez              1522
# 2         Mexico               Uruapan               301
# 3         Mexico              Irapuato               723
# 4         Mexico               Obregón               281
# 5      Venezuela               Caracas              2134
# 6         Mexico              Acapulco               600
# 7   South Africa             Cape Town              3065
# 8  United States             St. Louis               194
# 9         Brazil  Vitória da Conquista               205

# %%
top_homicide_cities.iloc[:10, 0:2]
#iloc[Columns , indexes]
# Out:
#          Country                  City
# 0         Mexico               Tijuana
# 1         Mexico                Juárez
# 2         Mexico               Uruapan
# 3         Mexico              Irapuato
# 4         Mexico               Obregón
# 5      Venezuela               Caracas
# 6         Mexico              Acapulco
# 7   South Africa             Cape Town
# 8  United States             St. Louis
# 9         Brazil  Vitória da Conquista

# %%
top_homicide_cities.iloc[:10, 2:3] * -1
# Out:
#    Homicides (2019)
# 0             -2367
# 1             -1522
# 2              -301
# 3              -723
# 4              -281
# 5             -2134
# 6              -600
# 7             -3065
# 8              -194
# 9              -205
