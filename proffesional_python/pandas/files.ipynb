# %%
import pandas as pd

# %% [markdown]
# # CSV

# %%
pd.read_csv('sources/bestsellers-with-categories.csv')
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
pd.read_csv('sources/bestsellers-with-categories.csv', sep = ',', header = 0, names = ["Nombre", 'Autor','Ranking', 'Reviews', 'Precio', 'Año', 'Genero'])
#read_csv(route, sep = "separeted value", header = "Header position", names = ['Manually name columns'])
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Ranking  Reviews  Precio   Año       Genero
# 0                    JJ Smith      4.7    17350       8  2016  Non Fiction
# 1                Stephen King      4.6     2052      22  2011      Fiction
# 2          Jordan B. Peterson      4.7    18979      15  2018  Non Fiction
# ...

# %% [markdown]
# # JSON

# %%
pd.read_json('sources/hpcharactersdataraw.json')
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
pd.read_json('sources/hpcharactersdataraw.json', typ = 'Series')
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %% [markdown]
# # OTHERS

# %%
#HTML
mr = pd.read_html('https://en.wikipedia.org/wiki/List_of_cities_by_homicide_rate')

# %%
mr[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            50 non-null     int64
#  1   City                            50 non-null     object
#  2   Country                         50 non-null     object
#  3   Homicides (2019)                50 non-null     int64
#  4   Population (2019)               50 non-null     int64
#  5   Homicides per 100,000 per year  50 non-null     float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.5+ KB

# %%
mr[0][0:25]
#mr[Select a table][Slicing]
# Out:
#     Rank                                 City        Country  \
# 0      1                              Tijuana         Mexico
# 1      2                               Juárez         Mexico
# 2      3                              Uruapan         Mexico
# 3      4                             Irapuato         Mexico
# 4      5                              Obregón         Mexico
# 5      6                              Caracas      Venezuela
# 6      7                             Acapulco         Mexico
# 7      8                            Cape Town   South Africa
# 8      9                            St. Louis  United States
# 9     10                 Vitória da Conquista         Brazil
# 10    11                            Baltimore  United States
# 11    12                       Ciudad Guayana      Venezuela
# 12    13                             Kingston        Jamaica
# 13    14                     Feira de Santana         Brazil
# ...

# %% [markdown]
# # Testing

# %%
data_frame = pd.read_csv('sources/IMDB-Movie-Data.csv')

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data_frame.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
pd.DataFrame(data_frame, range(0, 100))
# Out:
#     Rank                    Title                     Genre  \
# 0      1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1      2               Prometheus  Adventure,Mystery,Sci-Fi
# 2      3                    Split           Horror,Thriller
# 3      4                     Sing   Animation,Comedy,Family
# 4      5            Suicide Squad  Action,Adventure,Fantasy
# ..   ...                      ...                       ...
# 95    96            The Nice Guys       Action,Comedy,Crime
# 96    97            Kimi no na wa   Animation,Drama,Fantasy
# 97    98                 The Void     Horror,Mystery,Sci-Fi
# 98    99         Personal Shopper    Drama,Mystery,Thriller
# 99   100             The Departed      Crime,Drama,Thriller
#
#                                           Description              Director  \
# 0   A group of intergalactic criminals are forced ...            James Gunn
# 1   Following clues to the origin of mankind, a te...          Ridley Scott
# ...
