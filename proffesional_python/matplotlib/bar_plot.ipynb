# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
country = ['INDIA','JAPAN','MEXICO','COLOMBIA','GERMANY']
population = [1000,800,900,1000,300]

# %%
fig, ax= plt.subplots(figsize=(5,5))
plt.style.use('_mpl-gallery')
plt.bar(country, population, width= 0.5, color= ['#FA07FF', '#07DAFF', '#FFB207', '#07FF80','#9207FF'])
plt.xticks(np.arange(5),('India', 'Japon', 'Mexico','Colombia','Alemania'), rotation= 35, fontsize= 13)#Configutaciones en el eje x
plt.xlabel('Country',fontsize= 15)
plt.ylabel('Population', fontsize= 14)
plt.title('Population by country', fontsize= 15)
# Out:
# Text(0.5, 1.0, 'Population by country')

# %%
plt.barh(country,population)
plt.show()

# %% [markdown]
# # Test

# %%
plt.style.use('dark_background')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.9, 0.9])
plot.bar(country,population,width=0.5,color=['red','blue','yellow'])#(x,y, args*)
axes.set_title("Population by country")
fig.show()
# Out:
# /tmp/ipykernel_21169/1204083293.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
