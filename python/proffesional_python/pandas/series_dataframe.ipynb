# %%
import pandas as pd

# %%
team = pd.Series(
                ['Churumbel','Messi','Juan','El polluo'], 
                index = [4,3,2,1]
                )

# %%
team
# Out:
# 4    Churumbel
# 3        Messi
# 2         Juan
# 1    El polluo
# dtype: object

# %%
dick = {4: 'Churumbel',3: 'Messi',2: 'Juan',1: 'El polluo'}
pd.Series(dick)
# Out:
# 4    Churumbel
# 3        Messi
# 2         Juan
# 1    El polluo
# dtype: object

# %%
team[1]
# Out:
# 'El polluo'

# %%
team[0] #Enter from the items NOT from the indexes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Repositories/AiRoute/proffesional_python/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/Repositories/AiRoute/proffesional_python/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Repositories/AiRoute/proffesional_python/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# ...

# %%
team[0:2]
# Out:
# /tmp/ipykernel_20577/1801647479.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   team[0:2]
# 4    Churumbel
# 3        Messi
# dtype: object

# %%
frame = {
    "Personas" : ['Churumbel','Messi','Juan','El polluo'],
    "Altura" : [1.75,1.42,1.82,2.15],
    "Meneito" : [True, True, True, False]
}

# %%
pd.DataFrame(frame)
# Out:
#     Personas  Altura  Meneito
# 0  Churumbel    1.75     True
# 1      Messi    1.42     True
# 2       Juan    1.82     True
# 3  El polluo    2.15    False

# %%
pd.DataFrame(frame, index = ['F','A','R','C'])
# Out:
#     Personas  Altura  Meneito
# F  Churumbel    1.75     True
# A      Messi    1.42     True
# R       Juan    1.82     True
# C  El polluo    2.15    False

# %%
df_team = pd.DataFrame(frame, index = ['F','A','R','C'])

# %%
df_team.columns
# Out:
# Index(['Personas', 'Altura', 'Meneito'], dtype='object')

# %%
df_team.index
# Out:
# Index(['F', 'A', 'R', 'C'], dtype='object')
