# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sources/all_games.csv')
df_games = df.copy()
df_games['user_review'][df_games['user_review'] == 'tbd'] = np.nan
df_games['user_review'] = df_games['user_review'].astype('float32')
df_games.drop_duplicates(subset = ['name'], keep = 'first', inplace = True)
df_games
# Out:
# /tmp/ipykernel_7257/4011266623.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_games['user_review'][df_games['user_review'] == 'tbd'] = np.nan
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 5                              Super Mario Galaxy             Wii
# ...                                           ...             ...
# 18793                            Charlie's Angels        GameCube
# 18795                    Fast & Furious: Showdown        Xbox 360
# ...

# %%
df_games.groupby('platform').count()
# Out:
#                    name  release_date  summary  meta_score  user_review
# platform
#  3DS                340           340      338         340          326
#  DS                 585           585      583         585          485
#  Dreamcast          106           106      106         106          101
#  Game Boy Advance   357           357      352         357          294
#  GameCube           229           229      229         229          216
#  Nintendo 64         66            66       66          66           66
#  PC                3551          3551     3518        3551         3378
#  PSP                362           362      359         362          334
#  PlayStation        169           169      168         169          150
#  PlayStation 2      918           918      917         918          847
#  PlayStation 3      687           687      686         687          659
#  PlayStation 4     1041          1041     1028        1041          968
# ...

# %%
df_games.groupby('platform').mean()
# Out:
# /tmp/ipykernel_7257/120473676.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_games.groupby('platform').mean()
#                    meta_score  user_review
# platform
#  3DS                70.558824     7.167791
#  DS                 67.935043     7.263917
#  Dreamcast          75.301887     7.978218
#  Game Boy Advance   69.974790     7.563266
#  GameCube           69.842795     7.453704
#  Nintendo 64        78.863636     7.993939
#  PC                 71.825401     6.976317
#  PSP                69.024862     7.363772
#  PlayStation        73.911243     7.822667
#  PlayStation 2      69.468410     7.619598
#  PlayStation 3      70.292576     6.950835
#  PlayStation 4      70.283381     6.540496
#  PlayStation 5      75.328125     6.705357
# ...

# %%
df_games.groupby('platform').min()
# Out:
# /tmp/ipykernel_7257/1995297692.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df_games.groupby('platform').min()
#                                                name    release_date  \
# platform
#  3DS                             3D After Burner II  April 10, 2015
#  DS                               100 Classic Books  April 12, 2010
#  Dreamcast         18 Wheeler: American Pro Trucker  April 16, 2001
#  Game Boy Advance                   187 Ride or Die  April 10, 2005
#  GameCube                           1080: Avalanche  April 10, 2006
#  Nintendo 64           007: The World is Not Enough  April 26, 1999
#  PC                                  007: NightFire   April 1, 2005
#  PSP                                1000 Tiny Claws  April 12, 2005
# ...

# %%
df_games.groupby('platform').max().sort_values('meta_score')
# Out:
# /tmp/ipykernel_7257/4242733950.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df_games.groupby('platform').max().sort_values('meta_score')
#                                                     name        release_date  \
# platform
#  Stadia                         Super Bomberman R Online  September 30, 2003
#  PSP                                           echoshift   September 8, 2009
#  PlayStation 5                              Worms Rumble   September 7, 2021
#  Xbox Series X     Werewolf: The Apocalypse - Earthblood   September 9, 2021
#  DS                                                 Zubo   September 9, 2008
#  Wii U                                            ZombiU   September 8, 2016
#  PlayStation Vita            htoL#NiQ: The Firefly Diary   September 6, 2016
# ...

# %%
df_games.groupby('platform').max().sort_values('meta_score').reset_index()
# Out:
# /tmp/ipykernel_7257/3557460837.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df_games.groupby('platform').max().sort_values('meta_score').reset_index()
#              platform                                   name  \
# 0              Stadia               Super Bomberman R Online
# 1                 PSP                              echoshift
# 2       PlayStation 5                           Worms Rumble
# 3       Xbox Series X  Werewolf: The Apocalypse - Earthblood
# 4                  DS                                   Zubo
# 5               Wii U                                 ZombiU
# 6    PlayStation Vita            htoL#NiQ: The Firefly Diary
# 7                 3DS                           escapeVektor
# 8       PlayStation 4                   inFamous: Second Son
# ...

# %%
df_games.groupby('platform').agg(['min','max'])
# Out:
# /tmp/ipykernel_7257/3384587829.py:1: FutureWarning: ['summary'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_games.groupby('platform').agg(['min','max'])
#                                                name  \
#                                                 min
# platform
#  3DS                             3D After Burner II
#  DS                               100 Classic Books
#  Dreamcast         18 Wheeler: American Pro Trucker
#  Game Boy Advance                   187 Ride or Die
#  GameCube                           1080: Avalanche
#  Nintendo 64           007: The World is Not Enough
#  PC                                  007: NightFire
#  PSP                                1000 Tiny Claws
#  PlayStation           007: The World is not Enough
#  PlayStation 2          .hack//G.U. vol. 1//Rebirth
#  PlayStation 3                   1942: Joint Strike
# ...

# %%
df_games.groupby('platform').agg({'meta_score': ['min','max'], 'user_review': 'sum'})
# Out:
#                   meta_score       user_review
#                          min max           sum
# platform
#  3DS                      26  94   2336.699951
#  DS                       23  93   3523.000000
#  Dreamcast                43  98    805.799988
#  Game Boy Advance         26  95   2223.600098
#  GameCube                 23  97   1610.000000
#  Nintendo 64              39  99    527.599976
#  PC                       20  97  23566.000000
#  PSP                      28  91   2459.500000
#  PlayStation              25  98   1173.400024
#  PlayStation 2            24  97   6453.799805
#  PlayStation 3            30  98   4580.600098
#  PlayStation 4            21  95   6331.200195
#  PlayStation 5            51  92    375.500000
#  PlayStation Vita         33  93   1333.599976
#  Stadia                   48  81     29.200001
#  Switch                   29  97   5392.399902
#  Wii                      25  97   3074.100098
#  Wii U                    24  93    948.500000
# ...

# %%
df_games.groupby(['p','user_review']).count()
# Out:
#                         name  platform  release_date  summary
# meta_score user_review
# 20         1.7             1         1             1        1
# 21         2.9             1         1             1        1
# 22         1.3             1         1             1        1
#            1.7             1         1             1        1
# 23         2.8             1         1             1        1
# ...                      ...       ...           ...      ...
# 97         9.1             2         2             2        2
# 98         7.4             1         1             1        1
#            7.7             1         1             1        1
#            8.4             1         1             1        1
# 99         9.1             1         1             1        1
#
# [2526 rows x 4 columns]
