# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(3,2)) # Matrix 3 x 2
arr
# Out:
# array([[4, 8],
#        [8, 3],
#        [7, 9]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.reshape(1,6) # Matrix 1 x 6 = Vector
# Out:
# array([[4, 8, 8, 3, 7, 9]])

# %%
arr.reshape(2,3) # Matrix 2 x 3
# Out:
# array([[4, 8, 8],
#        [3, 7, 9]])

# %% [markdown]
# # Reshape according to different sources

# %%
arr
# Out:
# array([[4, 8],
#        [8, 3],
#        [7, 9]])

# %%
#default
np.reshape(arr,(2,3))
# Out:
# array([[4, 8, 8],
#        [3, 7, 9]])

# %%
# 'C' language
np.reshape(arr,(2,3),'C') #per rows
# Out:
# array([[4, 8, 8],
#        [3, 7, 9]])

# %%
# 'Fortran' language
np.reshape(arr,(2,3),'F') #per columns
# Out:
# array([[4, 7, 3],
#        [8, 8, 9]])

# %%
#according to the default configuration of memory saving in my system
np.reshape(arr,(2,3),'A')
# Out:
# array([[4, 8, 8],
#        [3, 7, 9]])

# %%
#imposible array reshape
np.reshape(arr,(5,7))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 #imposible array shape
# ----> 2 np.reshape(arr,(5,7))
#
# File <__array_function__ internals>:200, in reshape(*args, **kwargs)
#
# File ~/Repositories/AiRoute/proffesional_python/venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~/Repositories/AiRoute/proffesional_python/venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
# ...
